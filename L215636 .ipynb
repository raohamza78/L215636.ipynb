# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
# define procedure here

# %%
size=input("Enter Size of Matrix : ")

arr=[]
rows,cols=int(size),int(size)
for i in range(int(size)):
    col = []
    for j in range(int(size)):
        col.append(0)
    arr.append(col)

check=0

i=0
while i<int(size):
    j=0
    while j<int(size):
        arr[i][j]=input("Enter Data : ")
        j=j+1
    i=i+1
print(arr)


i=0
while i<int(size):
    j=0
    search=arr[i][j]
    j=j+1
    while j<int(size):
        if search==arr[i][j]:
            check=1
        j=j+1    
    i=i+1
    
i=0
while i<int(size):
    j=0
    search=arr[j][i]
    j=j+1
    while j<int(size):
        if search==arr[j][i]:
            check=1
        j=j+1    
    i=i+1
    
if arr[0][0].isnumeric()==0:
    check=1
    
if check==1:
    print("False")
else:
    print("True")

# %%
# run this block to test code after defining the procedure

test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]

print(check_input(test1)) # must return true
print(check_input(test2)) # must return false
print(check_input(test3)) # must return false

# %% [markdown]
# ---
# ## Question 2
# ---

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

temporary=pd.read_csv("StudentMarkSheet.csv")

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
row1 = temporary.shape[0]

temporary=temporary.dropna() 

row 2 = temporary.shape[0]

row3=row1-row2

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
task1=temporary[temporary["Student name"] == 'James Walker'] 

task2=temporary[temporary["Exam name"] == 'Biology'] 

Biology = task2["Marks"].mean()

task2=temporary[temporary["Exam name"] == 'Chemistry'] 

Chemistry = task2["Marks"].mean()

task2=temporary[temporary["Exam name"] == 'Mathematics'] 

Mathematics = task2["Marks"].mean()

task2=temporary[temporary["Exam name"] == 'Philosophy'] 

Philosophy = task2["Marks"].mean()

task2=temporary[temporary["Exam name"] == 'Physics'] 

Physics = task2["Marks"].mean()

task2=temporary[temporary["Exam name"] == 'Sociology'] 

Sociology= task2["Marks"].mean()

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
df = pd.DataFrame([('Biology', Biology),
                   ('Chemistry', Chemistry),
                   ('Mathematics', Mathematics),
                   ('Philosophy', Philosophy),
                  ('Physics', Physics),
                  ('Sociology',Sociology)],
           columns=('Exam name', 'Average Marks')
                 )
df

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
df.plot.bar(x='Exam name', y='Average Marks', rot=0);

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model

temporary=pd.read_csv("CatData.csv")

temporary=temporary.dropna()

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %% [markdown]
# Mass is independent
# Tail_length is dependent

# %%
# dependant variable: 
# independant variable:

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
def simple_linear_regression(Mass,Tail Length):
    
    Xi=Mass
    Yi=Tail Length
    n=len(xi)
    Xi_mean=Xi.mean()
    Yi_mean=Yi.mean()
    S_Xi=(Xi).sum()
    S_Yi=(Yi).sum()
    S_XiYi=((Xi*Yi).sum())*n
    S_Xi_S_Yi=S_Xi*S_Yi
    S_XiXi=((Xi*Xi).sum())*n
    S_Xi_Square=S_Xi*S_Xi
    slope=(S_XiYi-S_Xi_S_Yi)/(S_XiXi-S_Xi_Square)
    intercept=Yi_mean-slope*Xi_mean

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
print(slope)
print(intercept)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-01fdd235a913> in <module>
# ----> 1 print(slope)
#       2 print(intercept)
#
# NameError: name 'slope' is not defined

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
plt.scatter(temporary["Mass (kg)"],temporary["Tail Length (cm)"])
plt.plot(temporary["Mass (kg)"],slope*temporary["Mass (kg)"]+intercept,color="green")
plt.xlabel("Mass (kg)")
plt.ylabel("Tail Length (cm)")
plt.show()
